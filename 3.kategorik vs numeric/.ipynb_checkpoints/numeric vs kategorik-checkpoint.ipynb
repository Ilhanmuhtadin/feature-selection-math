# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats



import seaborn as sns
import statsmodels.api as sm
import pandas as pd



from scipy.stats import shapiro,normaltest,kstest,jarque_bera
import pingouin as pg
from pingouin import kruskal

# %%
def ubah_notasi_ilmiah(value):
    formatted_value = "{:.4f}".format(value) if isinstance(value, float) else value
    return formatted_value

def anova_t_tidak_normal_num(xx,yy,full_data,p_vall):
    panjang_x=len(yy.columns)
    dataaaa=[]

    
    dat=full_data[xx].describe().iloc[1]
    #print(dat)
    for i in range(panjang_x):

        
        
        #print('\n\n')
        if dat<2:
              print(dat,full_data[xx],'data mono')
                
                
                
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[xx]
            #print(data_s.unique())
            #print(data_s)
            unique_values = data_s.unique()
            #print([unique_values[0]])

            data_s_1=full_data[full_data[xx]==unique_values[0]][num.columns[i]]
            #print(data_s_1)
            data_s_2=full_data[full_data[xx]==unique_values[1]][num.columns[i]]
            #print(data_s_2)
            #print(len(data_s_1),len(data_s_2))


            ## now for the test

            t, p  = stats.mannwhitneyu(data_s_1, data_s_2)





            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                pakai='tidak'
                nilai='Accept null hypothesis'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                #print('Reject null hypothesis')
                pakai='iya'
            kesimp=[yy.columns[i],dat,'mannwhitneyu',ubah_notasi_ilmiah(p),nilai,pakai]
            dataaaa.append(kesimp)
            
            
            
            

        else:
            data_s=full_data[xx]
            unique_values = data_s.unique()

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx,yy.columns[i]]]
            pp = kruskal(data=data_ss,dv=yy.columns[i],between=xx)
            p=pp['p-unc'].iloc[0]




            if p >p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
                #print(p)
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
                #print(p)

            kesimp=[yy.columns[i],dat,'kruskal',ubah_notasi_ilmiah(p),nilai,pakai]
            dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa


def anova_t_normal_num(xx,yy,full_data,p_vall):
    panjang_x=len(yy.columns)
    dataaaa=[]
    
    dat=full_data[xx].describe().iloc[1]
    for i in range(panjang_x):

        
        
        

        #print('\n\n')
        if dat<2:
            print(dat,xx.columns[i],'data mono')
            
            
            
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[xx]
            #print(data_s)
            unique_values = data_s.unique()

            data_s_1=full_data[full_data[xx]==unique_values[0]][num.columns[i]]
            #print(data_s_1)
            data_s_2=full_data[full_data[xx]==unique_values[1]][num.columns[i]]
            #print(data_s_1)
            #print(data_s_2)


            # Performing the t-test
            t, p = stats.ttest_ind(data_s_1, data_s_2, equal_var=True)

            # Calculating the degrees of freedom
            df = len(data_s_1) + len(data_s_2) - 2

            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
            kesimp=[yy.columns[i],dat,'t test',ubah_notasi_ilmiah(p),nilai,pakai]
            dataaaa.append(kesimp)
            
            
            
        else:
            data_s=full_data[xx]
            unique_values = data_s.unique()

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx,yy.columns[i]]]

            pp=pg.anova(data=data_ss,dv=yy.columns[i],between=xx)
            p=pp['p-unc'].iloc[0]




            if p > p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
                #print(p)
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
                #print(p)

                kesimp=[yy.columns[i],dat,'anova',ubah_notasi_ilmiah(p),nilai,pakai]
                dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa

# %%
df = pd.read_csv('Ames_NO_Missing_Data.csv')
null_counts = df.isnull().sum()
columns_with_nulls = null_counts[null_counts > 0].index.tolist()
print("Columns with more than 0 null values:")
for col in columns_with_nulls:
    print(f"- {col}")
df.head()
# Out:
# Columns with more than 0 null values:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0           20        RL         141.0     31770   Pave       IR1
# 1           20        RH          80.0     11622   Pave       Reg
# 2           20        RL          81.0     14267   Pave       IR1
# 3           20        RL          93.0     11160   Pave       Reg
# 4           60        RL          74.0     13830   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch 3Ssn Porch  \
# 0          Lvl    AllPub     Corner        Gtl  ...              0          0
# 1          Lvl    AllPub     Inside        Gtl  ...              0          0
# 2          Lvl    AllPub     Corner        Gtl  ...              0          0
# 3          Lvl    AllPub     Corner        Gtl  ...              0          0
# 4          Lvl    AllPub     Inside        Gtl  ...              0          0
#
#   Screen Porch Pool Area Misc Val  Mo Sold  Yr Sold  Sale Type  \
# 0            0         0        0        5     2010        WD
# 1          120         0        0        6     2010        WD
# 2            0         0    12500        6     2010        WD
# 3            0         0        0        4     2010        WD
# 4            0         0        0        3     2010        WD
#
#    Sale Condition SalePrice
# 0          Normal    215000
# 1          Normal    105000
# 2          Normal    172000
# 3          Normal    244000
# 4          Normal    189900
#
# [5 rows x 76 columns]

# %%
num=df.select_dtypes(exclude='O')
num
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0              20    141.000000     31770             6             5
# 1              20     80.000000     11622             5             6
# 2              20     81.000000     14267             6             6
# 3              20     93.000000     11160             7             5
# 4              60     74.000000     13830             5             5
# ...           ...           ...       ...           ...           ...
# 2920           80     37.000000      7937             6             6
# 2921           20     75.144444      8885             5             5
# 2922           85     62.000000     10441             5             5
# 2923           20     77.000000     10010             5             5
# 2924           60     74.000000      9627             7             5
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0           1960            1960         112.0         639.0           0.0
# 1           1961            1961           0.0         468.0         144.0
# 2           1958            1958         108.0         923.0           0.0
# 3           1968            1968           0.0        1065.0           0.0
# 4           1997            1998           0.0         791.0           0.0
# ...          ...             ...           ...           ...           ...
# 2920        1984            1984           0.0         819.0           0.0
# 2921        1983            1983           0.0         301.0         324.0
# 2922        1992            1992           0.0         337.0           0.0
# 2923        1974            1975           0.0        1071.0         123.0
# 2924        1993            1994          94.0         758.0           0.0
#
#       ...  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0     ...           210             62               0           0
# 1     ...           140              0               0           0
# 2     ...           393             36               0           0
# 3     ...             0              0               0           0
# 4     ...           212             34               0           0
# ...   ...           ...            ...             ...         ...
# 2920  ...           120              0               0           0
# 2921  ...           164              0               0           0
# 2922  ...            80             32               0           0
# 2923  ...           240             38               0           0
# 2924  ...           190             48               0           0
#
#       Screen Porch  Pool Area  Misc Val  Mo Sold  Yr Sold  SalePrice
# 0                0          0         0        5     2010     215000
# 1              120          0         0        6     2010     105000
# 2                0          0     12500        6     2010     172000
# 3                0          0         0        4     2010     244000
# 4                0          0         0        3     2010     189900
# ...            ...        ...       ...      ...      ...        ...
# 2920             0          0         0        3     2006     142500
# 2921             0          0         0        6     2006     131000
# 2922             0          0       700        7     2006     132000
# 2923             0          0         0        4     2006     170000
# 2924             0          0         0       11     2006     188000
#
# [2925 rows x 37 columns]

# %%
data1=anova_t_normal_num('MS Zoning',num,df,0.05)
data1
# Out:
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     7   anova  0.0000  Reject null hypothesis        iya
# 1      Lot Frontage     7   anova  0.0000  Reject null hypothesis        iya
# 2          Lot Area     7   anova  0.0000  Reject null hypothesis        iya
# 3      Overall Qual     7   anova  0.0000  Reject null hypothesis        iya
# 4      Overall Cond     7   anova  0.0000  Reject null hypothesis        iya
# 5        Year Built     7   anova  0.0000  Reject null hypothesis        iya
# 6    Year Remod/Add     7   anova  0.0000  Reject null hypothesis        iya
# 7      Mas Vnr Area     7   anova  0.0000  Reject null hypothesis        iya
# 8      BsmtFin SF 1     7   anova  0.0000  Reject null hypothesis        iya
# 9      BsmtFin SF 2     7   anova  0.0001  Reject null hypothesis        iya
# 10      Bsmt Unf SF     7   anova  0.0013  Reject null hypothesis        iya
# 11    Total Bsmt SF     7   anova  0.0000  Reject null hypothesis        iya
# 12       1st Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 13       2nd Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 14  Low Qual Fin SF     7   anova  0.0075  Reject null hypothesis        iya
# 15      Gr Liv Area     7   anova  0.0000  Reject null hypothesis        iya
# 16   Bsmt Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 17   Bsmt Half Bath     7   anova  0.0358  Reject null hypothesis        iya
# 18        Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 19        Half Bath     7   anova  0.0000  Reject null hypothesis        iya
# 20    Bedroom AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 21    Kitchen AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 22    TotRms AbvGrd     7   anova  0.0000  Reject null hypothesis        iya
# 23       Fireplaces     7   anova  0.0000  Reject null hypothesis        iya
# 24    Garage Yr Blt     7   anova  0.0000  Reject null hypothesis        iya
# 25      Garage Cars     7   anova  0.0000  Reject null hypothesis        iya
# 26      Garage Area     7   anova  0.0000  Reject null hypothesis        iya
# 27     Wood Deck SF     7   anova  0.0000  Reject null hypothesis        iya
# 28    Open Porch SF     7   anova  0.0000  Reject null hypothesis        iya
# 29   Enclosed Porch     7   anova  0.0000  Reject null hypothesis        iya
# 30     Screen Porch     7   anova  0.0426  Reject null hypothesis        iya
# 31          Mo Sold     7   anova  0.0238  Reject null hypothesis        iya
# 32        SalePrice     7   anova  0.0000  Reject null hypothesis        iya

# %%
data1[data1['kesimpulan']=='iya']
# Out:
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     7   anova  0.0000  Reject null hypothesis        iya
# 1      Lot Frontage     7   anova  0.0000  Reject null hypothesis        iya
# 2          Lot Area     7   anova  0.0000  Reject null hypothesis        iya
# 3      Overall Qual     7   anova  0.0000  Reject null hypothesis        iya
# 4      Overall Cond     7   anova  0.0000  Reject null hypothesis        iya
# 5        Year Built     7   anova  0.0000  Reject null hypothesis        iya
# 6    Year Remod/Add     7   anova  0.0000  Reject null hypothesis        iya
# 7      Mas Vnr Area     7   anova  0.0000  Reject null hypothesis        iya
# 8      BsmtFin SF 1     7   anova  0.0000  Reject null hypothesis        iya
# 9      BsmtFin SF 2     7   anova  0.0001  Reject null hypothesis        iya
# 10      Bsmt Unf SF     7   anova  0.0013  Reject null hypothesis        iya
# 11    Total Bsmt SF     7   anova  0.0000  Reject null hypothesis        iya
# 12       1st Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 13       2nd Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 14  Low Qual Fin SF     7   anova  0.0075  Reject null hypothesis        iya
# 15      Gr Liv Area     7   anova  0.0000  Reject null hypothesis        iya
# 16   Bsmt Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 17   Bsmt Half Bath     7   anova  0.0358  Reject null hypothesis        iya
# 18        Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 19        Half Bath     7   anova  0.0000  Reject null hypothesis        iya
# 20    Bedroom AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 21    Kitchen AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 22    TotRms AbvGrd     7   anova  0.0000  Reject null hypothesis        iya
# 23       Fireplaces     7   anova  0.0000  Reject null hypothesis        iya
# 24    Garage Yr Blt     7   anova  0.0000  Reject null hypothesis        iya
# 25      Garage Cars     7   anova  0.0000  Reject null hypothesis        iya
# 26      Garage Area     7   anova  0.0000  Reject null hypothesis        iya
# 27     Wood Deck SF     7   anova  0.0000  Reject null hypothesis        iya
# 28    Open Porch SF     7   anova  0.0000  Reject null hypothesis        iya
# 29   Enclosed Porch     7   anova  0.0000  Reject null hypothesis        iya
# 30     Screen Porch     7   anova  0.0426  Reject null hypothesis        iya
# 31          Mo Sold     7   anova  0.0238  Reject null hypothesis        iya
# 32        SalePrice     7   anova  0.0000  Reject null hypothesis        iya

# %%
data1[data1['kesimpulan']=='tidak']
# Out:
# Empty DataFrame
# Columns: [nama, unik, testnya, p value, hasil hipotesis, kesimpulan]
# Index: []

# %%
data2=anova_t_normal_num('Street',num,df,0.05)
data2
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     2  t test  0.8995  Accept null hypothesis      tidak
# 1      Lot Frontage     2  t test  0.0102  Reject null hypothesis        iya
# 2          Lot Area     2  t test  0.0000  Reject null hypothesis        iya
# 3      Overall Qual     2  t test  0.0001  Reject null hypothesis        iya
# 4      Overall Cond     2  t test  0.3276  Accept null hypothesis      tidak
# 5        Year Built     2  t test  0.0008  Reject null hypothesis        iya
# 6    Year Remod/Add     2  t test  0.0000  Reject null hypothesis        iya
# 7      Mas Vnr Area     2  t test  0.2283  Accept null hypothesis      tidak
# 8      BsmtFin SF 1     2  t test  0.3604  Accept null hypothesis      tidak
# 9      BsmtFin SF 2     2  t test  0.6550  Accept null hypothesis      tidak
# 10      Bsmt Unf SF     2  t test  0.2710  Accept null hypothesis      tidak
# 11    Total Bsmt SF     2  t test  0.0553  Accept null hypothesis      tidak
# 12       1st Flr SF     2  t test  0.0606  Accept null hypothesis      tidak
# 13       2nd Flr SF     2  t test  0.0387  Reject null hypothesis        iya
# 14  Low Qual Fin SF     2  t test  0.7258  Accept null hypothesis      tidak
# 15      Gr Liv Area     2  t test  0.0011  Reject null hypothesis        iya
# 16   Bsmt Full Bath     2  t test  0.6450  Accept null hypothesis      tidak
# 17   Bsmt Half Bath     2  t test  0.3882  Accept null hypothesis      tidak
# 18        Full Bath     2  t test  0.0024  Reject null hypothesis        iya
# 19        Half Bath     2  t test  0.1428  Accept null hypothesis      tidak
# 20    Bedroom AbvGr     2  t test  0.0290  Reject null hypothesis        iya
# 21    Kitchen AbvGr     2  t test  0.4716  Accept null hypothesis      tidak
# 22    TotRms AbvGrd     2  t test  0.0047  Reject null hypothesis        iya
# 23       Fireplaces     2  t test  0.3293  Accept null hypothesis      tidak
# 24    Garage Yr Blt     2  t test  0.0582  Accept null hypothesis      tidak
# 25      Garage Cars     2  t test  0.4049  Accept null hypothesis      tidak
# 26      Garage Area     2  t test  0.8629  Accept null hypothesis      tidak
# 27     Wood Deck SF     2  t test  0.6030  Accept null hypothesis      tidak
# 28    Open Porch SF     2  t test  0.6973  Accept null hypothesis      tidak
# 29   Enclosed Porch     2  t test  0.0305  Reject null hypothesis        iya
# 30       3Ssn Porch     2  t test  0.7202  Accept null hypothesis      tidak
# 31     Screen Porch     2  t test  0.7159  Accept null hypothesis      tidak
# 32        Pool Area     2  t test  0.8341  Accept null hypothesis      tidak
# 33         Misc Val     2  t test  0.6350  Accept null hypothesis      tidak
# 34          Mo Sold     2  t test  0.3591  Accept null hypothesis      tidak
# 35          Yr Sold     2  t test  0.3225  Accept null hypothesis      tidak
# 36        SalePrice     2  t test  0.0013  Reject null hypothesis        iya

# %%
data2[data2['kesimpulan']=='iya']
# Out:
#               nama  unik testnya p value         hasil hipotesis kesimpulan
# 1     Lot Frontage     2  t test  0.0102  Reject null hypothesis        iya
# 2         Lot Area     2  t test  0.0000  Reject null hypothesis        iya
# 3     Overall Qual     2  t test  0.0001  Reject null hypothesis        iya
# 5       Year Built     2  t test  0.0008  Reject null hypothesis        iya
# 6   Year Remod/Add     2  t test  0.0000  Reject null hypothesis        iya
# 13      2nd Flr SF     2  t test  0.0387  Reject null hypothesis        iya
# 15     Gr Liv Area     2  t test  0.0011  Reject null hypothesis        iya
# 18       Full Bath     2  t test  0.0024  Reject null hypothesis        iya
# 20   Bedroom AbvGr     2  t test  0.0290  Reject null hypothesis        iya
# 22   TotRms AbvGrd     2  t test  0.0047  Reject null hypothesis        iya
# 29  Enclosed Porch     2  t test  0.0305  Reject null hypothesis        iya
# 36       SalePrice     2  t test  0.0013  Reject null hypothesis        iya

# %%
data2[data2['kesimpulan']=='tidak']
# Out:
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     2  t test  0.8995  Accept null hypothesis      tidak
# 4      Overall Cond     2  t test  0.3276  Accept null hypothesis      tidak
# 7      Mas Vnr Area     2  t test  0.2283  Accept null hypothesis      tidak
# 8      BsmtFin SF 1     2  t test  0.3604  Accept null hypothesis      tidak
# 9      BsmtFin SF 2     2  t test  0.6550  Accept null hypothesis      tidak
# 10      Bsmt Unf SF     2  t test  0.2710  Accept null hypothesis      tidak
# 11    Total Bsmt SF     2  t test  0.0553  Accept null hypothesis      tidak
# 12       1st Flr SF     2  t test  0.0606  Accept null hypothesis      tidak
# 14  Low Qual Fin SF     2  t test  0.7258  Accept null hypothesis      tidak
# 16   Bsmt Full Bath     2  t test  0.6450  Accept null hypothesis      tidak
# 17   Bsmt Half Bath     2  t test  0.3882  Accept null hypothesis      tidak
# 19        Half Bath     2  t test  0.1428  Accept null hypothesis      tidak
# 21    Kitchen AbvGr     2  t test  0.4716  Accept null hypothesis      tidak
# 23       Fireplaces     2  t test  0.3293  Accept null hypothesis      tidak
# 24    Garage Yr Blt     2  t test  0.0582  Accept null hypothesis      tidak
# 25      Garage Cars     2  t test  0.4049  Accept null hypothesis      tidak
# 26      Garage Area     2  t test  0.8629  Accept null hypothesis      tidak
# 27     Wood Deck SF     2  t test  0.6030  Accept null hypothesis      tidak
# 28    Open Porch SF     2  t test  0.6973  Accept null hypothesis      tidak
# 30       3Ssn Porch     2  t test  0.7202  Accept null hypothesis      tidak
# 31     Screen Porch     2  t test  0.7159  Accept null hypothesis      tidak
# 32        Pool Area     2  t test  0.8341  Accept null hypothesis      tidak
# 33         Misc Val     2  t test  0.6350  Accept null hypothesis      tidak
# 34          Mo Sold     2  t test  0.3591  Accept null hypothesis      tidak
# 35          Yr Sold     2  t test  0.3225  Accept null hypothesis      tidak

# %%
data3=anova_t_normal_num('Street',num,df,0.05)
data3
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     2  t test  0.8995  Accept null hypothesis      tidak
# 1      Lot Frontage     2  t test  0.0102  Reject null hypothesis        iya
# 2          Lot Area     2  t test  0.0000  Reject null hypothesis        iya
# 3      Overall Qual     2  t test  0.0001  Reject null hypothesis        iya
# 4      Overall Cond     2  t test  0.3276  Accept null hypothesis      tidak
# 5        Year Built     2  t test  0.0008  Reject null hypothesis        iya
# 6    Year Remod/Add     2  t test  0.0000  Reject null hypothesis        iya
# 7      Mas Vnr Area     2  t test  0.2283  Accept null hypothesis      tidak
# 8      BsmtFin SF 1     2  t test  0.3604  Accept null hypothesis      tidak
# 9      BsmtFin SF 2     2  t test  0.6550  Accept null hypothesis      tidak
# 10      Bsmt Unf SF     2  t test  0.2710  Accept null hypothesis      tidak
# 11    Total Bsmt SF     2  t test  0.0553  Accept null hypothesis      tidak
# 12       1st Flr SF     2  t test  0.0606  Accept null hypothesis      tidak
# 13       2nd Flr SF     2  t test  0.0387  Reject null hypothesis        iya
# 14  Low Qual Fin SF     2  t test  0.7258  Accept null hypothesis      tidak
# 15      Gr Liv Area     2  t test  0.0011  Reject null hypothesis        iya
# 16   Bsmt Full Bath     2  t test  0.6450  Accept null hypothesis      tidak
# 17   Bsmt Half Bath     2  t test  0.3882  Accept null hypothesis      tidak
# 18        Full Bath     2  t test  0.0024  Reject null hypothesis        iya
# 19        Half Bath     2  t test  0.1428  Accept null hypothesis      tidak
# 20    Bedroom AbvGr     2  t test  0.0290  Reject null hypothesis        iya
# 21    Kitchen AbvGr     2  t test  0.4716  Accept null hypothesis      tidak
# 22    TotRms AbvGrd     2  t test  0.0047  Reject null hypothesis        iya
# 23       Fireplaces     2  t test  0.3293  Accept null hypothesis      tidak
# 24    Garage Yr Blt     2  t test  0.0582  Accept null hypothesis      tidak
# 25      Garage Cars     2  t test  0.4049  Accept null hypothesis      tidak
# 26      Garage Area     2  t test  0.8629  Accept null hypothesis      tidak
# 27     Wood Deck SF     2  t test  0.6030  Accept null hypothesis      tidak
# 28    Open Porch SF     2  t test  0.6973  Accept null hypothesis      tidak
# 29   Enclosed Porch     2  t test  0.0305  Reject null hypothesis        iya
# 30       3Ssn Porch     2  t test  0.7202  Accept null hypothesis      tidak
# 31     Screen Porch     2  t test  0.7159  Accept null hypothesis      tidak
# 32        Pool Area     2  t test  0.8341  Accept null hypothesis      tidak
# 33         Misc Val     2  t test  0.6350  Accept null hypothesis      tidak
# 34          Mo Sold     2  t test  0.3591  Accept null hypothesis      tidak
# 35          Yr Sold     2  t test  0.3225  Accept null hypothesis      tidak
# 36        SalePrice     2  t test  0.0013  Reject null hypothesis        iya

# %%
data3[data3['kesimpulan']=='iya']
# Out:
#               nama  unik testnya p value         hasil hipotesis kesimpulan
# 1     Lot Frontage     2  t test  0.0102  Reject null hypothesis        iya
# 2         Lot Area     2  t test  0.0000  Reject null hypothesis        iya
# 3     Overall Qual     2  t test  0.0001  Reject null hypothesis        iya
# 5       Year Built     2  t test  0.0008  Reject null hypothesis        iya
# 6   Year Remod/Add     2  t test  0.0000  Reject null hypothesis        iya
# 13      2nd Flr SF     2  t test  0.0387  Reject null hypothesis        iya
# 15     Gr Liv Area     2  t test  0.0011  Reject null hypothesis        iya
# 18       Full Bath     2  t test  0.0024  Reject null hypothesis        iya
# 20   Bedroom AbvGr     2  t test  0.0290  Reject null hypothesis        iya
# 22   TotRms AbvGrd     2  t test  0.0047  Reject null hypothesis        iya
# 29  Enclosed Porch     2  t test  0.0305  Reject null hypothesis        iya
# 36       SalePrice     2  t test  0.0013  Reject null hypothesis        iya

# %%
data3[data3['kesimpulan']=='tidak']
# Out:
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     2  t test  0.8995  Accept null hypothesis      tidak
# 4      Overall Cond     2  t test  0.3276  Accept null hypothesis      tidak
# 7      Mas Vnr Area     2  t test  0.2283  Accept null hypothesis      tidak
# 8      BsmtFin SF 1     2  t test  0.3604  Accept null hypothesis      tidak
# 9      BsmtFin SF 2     2  t test  0.6550  Accept null hypothesis      tidak
# 10      Bsmt Unf SF     2  t test  0.2710  Accept null hypothesis      tidak
# 11    Total Bsmt SF     2  t test  0.0553  Accept null hypothesis      tidak
# 12       1st Flr SF     2  t test  0.0606  Accept null hypothesis      tidak
# 14  Low Qual Fin SF     2  t test  0.7258  Accept null hypothesis      tidak
# 16   Bsmt Full Bath     2  t test  0.6450  Accept null hypothesis      tidak
# 17   Bsmt Half Bath     2  t test  0.3882  Accept null hypothesis      tidak
# 19        Half Bath     2  t test  0.1428  Accept null hypothesis      tidak
# 21    Kitchen AbvGr     2  t test  0.4716  Accept null hypothesis      tidak
# 23       Fireplaces     2  t test  0.3293  Accept null hypothesis      tidak
# 24    Garage Yr Blt     2  t test  0.0582  Accept null hypothesis      tidak
# 25      Garage Cars     2  t test  0.4049  Accept null hypothesis      tidak
# 26      Garage Area     2  t test  0.8629  Accept null hypothesis      tidak
# 27     Wood Deck SF     2  t test  0.6030  Accept null hypothesis      tidak
# 28    Open Porch SF     2  t test  0.6973  Accept null hypothesis      tidak
# 30       3Ssn Porch     2  t test  0.7202  Accept null hypothesis      tidak
# 31     Screen Porch     2  t test  0.7159  Accept null hypothesis      tidak
# 32        Pool Area     2  t test  0.8341  Accept null hypothesis      tidak
# 33         Misc Val     2  t test  0.6350  Accept null hypothesis      tidak
# 34          Mo Sold     2  t test  0.3591  Accept null hypothesis      tidak
# 35          Yr Sold     2  t test  0.3225  Accept null hypothesis      tidak

# %%
data4=anova_t_normal_num('MS Zoning',num,df,0.05)
data4
# Out:
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     7   anova  0.0000  Reject null hypothesis        iya
# 1      Lot Frontage     7   anova  0.0000  Reject null hypothesis        iya
# 2          Lot Area     7   anova  0.0000  Reject null hypothesis        iya
# 3      Overall Qual     7   anova  0.0000  Reject null hypothesis        iya
# 4      Overall Cond     7   anova  0.0000  Reject null hypothesis        iya
# 5        Year Built     7   anova  0.0000  Reject null hypothesis        iya
# 6    Year Remod/Add     7   anova  0.0000  Reject null hypothesis        iya
# 7      Mas Vnr Area     7   anova  0.0000  Reject null hypothesis        iya
# 8      BsmtFin SF 1     7   anova  0.0000  Reject null hypothesis        iya
# 9      BsmtFin SF 2     7   anova  0.0001  Reject null hypothesis        iya
# 10      Bsmt Unf SF     7   anova  0.0013  Reject null hypothesis        iya
# 11    Total Bsmt SF     7   anova  0.0000  Reject null hypothesis        iya
# 12       1st Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 13       2nd Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 14  Low Qual Fin SF     7   anova  0.0075  Reject null hypothesis        iya
# 15      Gr Liv Area     7   anova  0.0000  Reject null hypothesis        iya
# 16   Bsmt Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 17   Bsmt Half Bath     7   anova  0.0358  Reject null hypothesis        iya
# 18        Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 19        Half Bath     7   anova  0.0000  Reject null hypothesis        iya
# 20    Bedroom AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 21    Kitchen AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 22    TotRms AbvGrd     7   anova  0.0000  Reject null hypothesis        iya
# 23       Fireplaces     7   anova  0.0000  Reject null hypothesis        iya
# 24    Garage Yr Blt     7   anova  0.0000  Reject null hypothesis        iya
# 25      Garage Cars     7   anova  0.0000  Reject null hypothesis        iya
# 26      Garage Area     7   anova  0.0000  Reject null hypothesis        iya
# 27     Wood Deck SF     7   anova  0.0000  Reject null hypothesis        iya
# 28    Open Porch SF     7   anova  0.0000  Reject null hypothesis        iya
# 29   Enclosed Porch     7   anova  0.0000  Reject null hypothesis        iya
# 30     Screen Porch     7   anova  0.0426  Reject null hypothesis        iya
# 31          Mo Sold     7   anova  0.0238  Reject null hypothesis        iya
# 32        SalePrice     7   anova  0.0000  Reject null hypothesis        iya

# %%
data4[data4['kesimpulan']=='tidak']
# Out:
# Empty DataFrame
# Columns: [nama, unik, testnya, p value, hasil hipotesis, kesimpulan]
# Index: []

# %%
data4[data4['kesimpulan']=='iya']
# Out:
#                nama  unik testnya p value         hasil hipotesis kesimpulan
# 0       MS SubClass     7   anova  0.0000  Reject null hypothesis        iya
# 1      Lot Frontage     7   anova  0.0000  Reject null hypothesis        iya
# 2          Lot Area     7   anova  0.0000  Reject null hypothesis        iya
# 3      Overall Qual     7   anova  0.0000  Reject null hypothesis        iya
# 4      Overall Cond     7   anova  0.0000  Reject null hypothesis        iya
# 5        Year Built     7   anova  0.0000  Reject null hypothesis        iya
# 6    Year Remod/Add     7   anova  0.0000  Reject null hypothesis        iya
# 7      Mas Vnr Area     7   anova  0.0000  Reject null hypothesis        iya
# 8      BsmtFin SF 1     7   anova  0.0000  Reject null hypothesis        iya
# 9      BsmtFin SF 2     7   anova  0.0001  Reject null hypothesis        iya
# 10      Bsmt Unf SF     7   anova  0.0013  Reject null hypothesis        iya
# 11    Total Bsmt SF     7   anova  0.0000  Reject null hypothesis        iya
# 12       1st Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 13       2nd Flr SF     7   anova  0.0000  Reject null hypothesis        iya
# 14  Low Qual Fin SF     7   anova  0.0075  Reject null hypothesis        iya
# 15      Gr Liv Area     7   anova  0.0000  Reject null hypothesis        iya
# 16   Bsmt Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 17   Bsmt Half Bath     7   anova  0.0358  Reject null hypothesis        iya
# 18        Full Bath     7   anova  0.0000  Reject null hypothesis        iya
# 19        Half Bath     7   anova  0.0000  Reject null hypothesis        iya
# 20    Bedroom AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 21    Kitchen AbvGr     7   anova  0.0000  Reject null hypothesis        iya
# 22    TotRms AbvGrd     7   anova  0.0000  Reject null hypothesis        iya
# 23       Fireplaces     7   anova  0.0000  Reject null hypothesis        iya
# 24    Garage Yr Blt     7   anova  0.0000  Reject null hypothesis        iya
# 25      Garage Cars     7   anova  0.0000  Reject null hypothesis        iya
# 26      Garage Area     7   anova  0.0000  Reject null hypothesis        iya
# 27     Wood Deck SF     7   anova  0.0000  Reject null hypothesis        iya
# 28    Open Porch SF     7   anova  0.0000  Reject null hypothesis        iya
# 29   Enclosed Porch     7   anova  0.0000  Reject null hypothesis        iya
# 30     Screen Porch     7   anova  0.0426  Reject null hypothesis        iya
# 31          Mo Sold     7   anova  0.0238  Reject null hypothesis        iya
# 32        SalePrice     7   anova  0.0000  Reject null hypothesis        iya

# %%
sns.boxplot(data=df,x='Street',y='MS SubClass')#tidak
# Out:
# <Axes: xlabel='Street', ylabel='MS SubClass'>

# %%
sns.boxplot(data=df,x='Street',y='Lot Frontage')#iya
# Out:
# <Axes: xlabel='Street', ylabel='Lot Frontage'>
