# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('Advertising.csv')
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# # correlation
# ### drop correlation > 0.85
# use correlation feature or Variance(low)

# %%
plt.figure(figsize=(8,8),dpi=100)
sns.heatmap(df.corr('pearson'),annot=True)
plt.show()

# %%
plt.figure(figsize=(8,8),dpi=100)
sns.heatmap(df.corr('kendall'),annot=True)
plt.show()

# %%
plt.figure(figsize=(8,8),dpi=100)
sns.heatmap(df.corr('spearman'),annot=True)
plt.show()

# %% [markdown]
# # Variance

# %%
X=df.drop(columns=['sales'])
# Check the variance of each column
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
variance_df = pd.DataFrame(variances, columns=['variansi'])
variance_df
# Out:
#               variansi
# TV         7370.949893
# radio       220.427743
# newspaper   474.308326

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=0)
selector.fit_transform(X)
selector.get_support()
for i in X.columns[selector.get_support()]:
    print(i)
# Out:
# TV
# radio
# newspaper

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=221)
selector.fit_transform(X)
selector.get_support()
for i in X.columns[selector.get_support()]:
    print(i)
# Out:
# TV
# newspaper
