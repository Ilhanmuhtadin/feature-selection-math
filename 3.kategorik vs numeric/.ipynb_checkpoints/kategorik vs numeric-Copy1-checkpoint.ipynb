# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats



import seaborn as sns
import statsmodels.api as sm
import pandas as pd



from scipy.stats import shapiro,normaltest,kstest,jarque_bera
import pingouin as pg
from pingouin import kruskal

# %%
def ubah_notasi_ilmiah(value):
    formatted_value = "{:.4f}".format(value) if isinstance(value, float) else value
    return formatted_value
def anova_t_tidak_normal(xx,yy,full_data,p_vall):
    panjang_x=len(xx.columns)
    dataaaa=[]

    for i in range(panjang_x):

        dat=xx.describe().iloc[1][i]

        #print('\n\n')
        if dat<2:
              print(dat,xx.columns[i],'data mono')
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[[xx.columns[i]]]
            #print(data_s)
            unique_values = data_s.apply(lambda x: x.unique())

            data_s_1=full_data[full_data[xx.columns[i]]==unique_values.iloc[0][0]][yy]
            data_s_2=full_data[full_data[xx.columns[i]]==unique_values.iloc[1][0]][yy]
            #print(data_s_1)
            #print(data_s_2)


            ## now for the test

            t, p  = stats.mannwhitneyu(data_s_1, data_s_2)





            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                pakai='tidak'
                nilai='Accept null hypothesis'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                #print('Reject null hypothesis')
                pakai='iya'
            kesimp=[xx.columns[i],dat,'mannwhitneyu',p,nilai,pakai]
            dataaaa.append(kesimp)
        else:
            data_s=full_data[[xx.columns[i]]]
            unique_values = data_s.apply(lambda x: x.unique())

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx.columns[i],yy]]
            pp = kruskal(data=data_ss,dv=yy,between=xx.columns[i])
            p=pp['p-unc'].iloc[0]




        if p >p_vall:
            nilai='Accept null hypothesis'
            pakai='tidak'
            #print('Accept null hypothesis')
            #print(p)
        else:
            nilai='Reject null hypothesis'
            pakai='iya'
            #print('Reject null hypothesis')
            #print(p)

        kesimp=[xx.columns[i],dat,'kruskal',ubah_notasi_ilmiah(p),nilai,pakai]
        dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa
def anova_t_normal(xx,yy,full_data,p_vall):
    panjang_x=len(yy.columns)
    dataaaa=[]
    
    dat=full_data[xx].describe().iloc[1]
    for i in range(panjang_x):

        
        
        

        #print('\n\n')
        if dat<2:
            print(dat,xx.columns[i],'data mono')
            
            
            
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[xx]
            #print(data_s)
            unique_values = data_s.unique()

            data_s_1=full_data[full_data[xx]==unique_values[0]][num.columns[i]]
            #print(data_s_1)
            data_s_2=full_data[full_data[xx]==unique_values[1]][num.columns[i]]
            #print(data_s_1)
            #print(data_s_2)


            # Performing the t-test
            t, p = stats.ttest_ind(data_s_1, data_s_2, equal_var=True)

            # Calculating the degrees of freedom
            df = len(data_s_1) + len(data_s_2) - 2

            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
            kesimp=[yy.columns[i],dat,'t test',p,nilai,pakai]
            dataaaa.append(kesimp)
            
            
            
        else:
            data_s=full_data[xx]
            unique_values = data_s.unique()

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx,yy.columns[i]]]

            pp=pg.anova(data=data_ss,dv=yy.columns[i],between=xx)
            p=pp['p-unc'].iloc[0]




        if p > p_vall:
            nilai='Accept null hypothesis'
            pakai='tidak'
            #print('Accept null hypothesis')
            #print(p)
        else:
            nilai='Reject null hypothesis'
            pakai='iya'
            #print('Reject null hypothesis')
            #print(p)

        kesimp=[yy.columns[i],dat,'anova',ubah_notasi_ilmiah(p),nilai,pakai]
        dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa

# %%
df = pd.read_csv('Ames_NO_Missing_Data.csv')
null_counts = df.isnull().sum()
columns_with_nulls = null_counts[null_counts > 0].index.tolist()
print("Columns with more than 0 null values:")
for col in columns_with_nulls:
    print(f"- {col}")
df.head()
# Out:
# Columns with more than 0 null values:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0           20        RL         141.0     31770   Pave       IR1
# 1           20        RH          80.0     11622   Pave       Reg
# 2           20        RL          81.0     14267   Pave       IR1
# 3           20        RL          93.0     11160   Pave       Reg
# 4           60        RL          74.0     13830   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch 3Ssn Porch  \
# 0          Lvl    AllPub     Corner        Gtl  ...              0          0
# 1          Lvl    AllPub     Inside        Gtl  ...              0          0
# 2          Lvl    AllPub     Corner        Gtl  ...              0          0
# 3          Lvl    AllPub     Corner        Gtl  ...              0          0
# 4          Lvl    AllPub     Inside        Gtl  ...              0          0
#
#   Screen Porch Pool Area Misc Val  Mo Sold  Yr Sold  Sale Type  \
# 0            0         0        0        5     2010        WD
# 1          120         0        0        6     2010        WD
# 2            0         0    12500        6     2010        WD
# 3            0         0        0        4     2010        WD
# 4            0         0        0        3     2010        WD
#
#    Sale Condition SalePrice
# 0          Normal    215000
# 1          Normal    105000
# 2          Normal    172000
# 3          Normal    244000
# 4          Normal    189900
#
# [5 rows x 76 columns]

# %%
num=df.select_dtypes(exclude='O')

# %%
num
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0              20    141.000000     31770             6             5
# 1              20     80.000000     11622             5             6
# 2              20     81.000000     14267             6             6
# 3              20     93.000000     11160             7             5
# 4              60     74.000000     13830             5             5
# ...           ...           ...       ...           ...           ...
# 2920           80     37.000000      7937             6             6
# 2921           20     75.144444      8885             5             5
# 2922           85     62.000000     10441             5             5
# 2923           20     77.000000     10010             5             5
# 2924           60     74.000000      9627             7             5
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0           1960            1960         112.0         639.0           0.0
# 1           1961            1961           0.0         468.0         144.0
# 2           1958            1958         108.0         923.0           0.0
# 3           1968            1968           0.0        1065.0           0.0
# 4           1997            1998           0.0         791.0           0.0
# ...          ...             ...           ...           ...           ...
# 2920        1984            1984           0.0         819.0           0.0
# 2921        1983            1983           0.0         301.0         324.0
# 2922        1992            1992           0.0         337.0           0.0
# 2923        1974            1975           0.0        1071.0         123.0
# 2924        1993            1994          94.0         758.0           0.0
#
#       ...  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0     ...           210             62               0           0
# 1     ...           140              0               0           0
# 2     ...           393             36               0           0
# 3     ...             0              0               0           0
# 4     ...           212             34               0           0
# ...   ...           ...            ...             ...         ...
# 2920  ...           120              0               0           0
# 2921  ...           164              0               0           0
# 2922  ...            80             32               0           0
# 2923  ...           240             38               0           0
# 2924  ...           190             48               0           0
#
#       Screen Porch  Pool Area  Misc Val  Mo Sold  Yr Sold  SalePrice
# 0                0          0         0        5     2010     215000
# 1              120          0         0        6     2010     105000
# 2                0          0     12500        6     2010     172000
# 3                0          0         0        4     2010     244000
# 4                0          0         0        3     2010     189900
# ...            ...        ...       ...      ...      ...        ...
# 2920             0          0         0        3     2006     142500
# 2921             0          0         0        6     2006     131000
# 2922             0          0       700        7     2006     132000
# 2923             0          0         0        4     2006     170000
# 2924             0          0         0       11     2006     188000
#
# [2925 rows x 37 columns]

# %%
df[df['Street']=='Pave'][num.columns[0]]
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       60
#         ..
# 2920    80
# 2921    20
# 2922    85
# 2923    20
# 2924    60
# Name: MS SubClass, Length: 2913, dtype: int64

# %%
df[df['Street']=='Pave'][num.columns[0]]
# Out:
# 'MS SubClass'

# %%
def ubah_notasi_ilmiah(value):
    formatted_value = "{:.4f}".format(value) if isinstance(value, float) else value
    return formatted_value

def anova_t_tidak_normal(xx,yy,full_data,p_vall):
    panjang_x=len(yy.columns)
    dataaaa=[]

    
    dat=full_data[xx].describe().iloc[1]
    #print(dat)
    for i in range(panjang_x):

        #print('\n\n')
        if dat<2:
              print(dat,full_data[xx],'data mono')
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[xx]
            #print(data_s.unique())
            #print(data_s)
            unique_values = data_s.unique()
            #print([unique_values[0]])

            data_s_1=full_data[full_data[xx]==unique_values[0]][num.columns[i]]
            #print(data_s_1)
            data_s_2=full_data[full_data[xx]==unique_values[1]][num.columns[i]]
            #print(data_s_2)
            #print(len(data_s_1),len(data_s_2))


            ## now for the test

            t, p  = stats.mannwhitneyu(data_s_1, data_s_2)





            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                pakai='tidak'
                nilai='Accept null hypothesis'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                #print('Reject null hypothesis')
                pakai='iya'
            kesimp=[yy.columns[i],dat,'mannwhitneyu',ubah_notasi_ilmiah(p),nilai,pakai]
            dataaaa.append(kesimp)

        else:
            data_s=full_data[xx]
            unique_values = data_s.unique()

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx,yy.columns[i]]]
            pp = kruskal(data=data_ss,dv=yy,between=xx.columns[i])
            p=pp['p-unc'].iloc[0]




            if p >p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
                #print(p)
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
                #print(p)

            kesimp=[xx.columns[i],dat,'kruskal',ubah_notasi_ilmiah(p),nilai,pakai]
            dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa


def anova_t_normal(xx,yy,full_data,p_vall):
    panjang_x=len(xx.columns)
    dataaaa=[]

    for i in range(panjang_x):

        dat=xx.describe().iloc[1][i]

        #print('\n\n')
        if dat<2:
            print(dat,xx.columns[i],'data mono')
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[[xx.columns[i]]]
            #print(data_s)
            unique_values = data_s.apply(lambda x: x.unique())

            data_s_1=full_data[full_data[xx.columns[i]]==unique_values.iloc[0][0]][yy]
            data_s_2=full_data[full_data[xx.columns[i]]==unique_values.iloc[1][0]][yy]
            #print(data_s_1)
            #print(data_s_2)


            # Performing the t-test
            t, p = stats.ttest_ind(data_s_1, data_s_2, equal_var=True)

            # Calculating the degrees of freedom
            df = len(data_s_1) + len(data_s_2) - 2

            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
            kesimp=[xx.columns[i],dat,'t test',p,nilai,pakai]
            dataaaa.append(kesimp)
        else:
            data_s=full_data[[xx.columns[i]]]
            unique_values = data_s.apply(lambda x: x.unique())

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx.columns[i],yy]]

            pp=pg.anova(data=data_ss,dv=yy,between=xx.columns[i])
            p=pp['p-unc'].iloc[0]




        if p > p_vall:
            nilai='Accept null hypothesis'
            pakai='tidak'
            #print('Accept null hypothesis')
            #print(p)
        else:
            nilai='Reject null hypothesis'
            pakai='iya'
            #print('Reject null hypothesis')
            #print(p)

        kesimp=[xx.columns[i],dat,'anova',ubah_notasi_ilmiah(p),nilai,pakai]
        dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa
data=anova_t_tidak_normal('Street',num,df,0.05)
data
# Out:
#                nama  unik       testnya p value         hasil hipotesis  \
# 0       MS SubClass     2  mannwhitneyu  0.9884  Accept null hypothesis
# 1      Lot Frontage     2  mannwhitneyu  0.1743  Accept null hypothesis
# 2          Lot Area     2  mannwhitneyu  0.0675  Accept null hypothesis
# 3      Overall Qual     2  mannwhitneyu  0.0005  Reject null hypothesis
# 4      Overall Cond     2  mannwhitneyu  0.3729  Accept null hypothesis
# 5        Year Built     2  mannwhitneyu  0.0015  Reject null hypothesis
# 6    Year Remod/Add     2  mannwhitneyu  0.0000  Reject null hypothesis
# 7      Mas Vnr Area     2  mannwhitneyu  0.2357  Accept null hypothesis
# 8      BsmtFin SF 1     2  mannwhitneyu  0.2111  Accept null hypothesis
# 9      BsmtFin SF 2     2  mannwhitneyu  0.6153  Accept null hypothesis
# 10      Bsmt Unf SF     2  mannwhitneyu  0.3568  Accept null hypothesis
# 11    Total Bsmt SF     2  mannwhitneyu  0.0534  Accept null hypothesis
# 12       1st Flr SF     2  mannwhitneyu  0.0432  Reject null hypothesis
# 13       2nd Flr SF     2  mannwhitneyu  0.0661  Accept null hypothesis
# 14  Low Qual Fin SF     2  mannwhitneyu  0.6834  Accept null hypothesis
# 15      Gr Liv Area     2  mannwhitneyu  0.0002  Reject null hypothesis
# 16   Bsmt Full Bath     2  mannwhitneyu  0.8372  Accept null hypothesis
# 17   Bsmt Half Bath     2  mannwhitneyu  0.3830  Accept null hypothesis
# 18        Full Bath     2  mannwhitneyu  0.0016  Reject null hypothesis
# 19        Half Bath     2  mannwhitneyu  0.1416  Accept null hypothesis
# 20    Bedroom AbvGr     2  mannwhitneyu  0.0372  Reject null hypothesis
# 21    Kitchen AbvGr     2  mannwhitneyu  0.4679  Accept null hypothesis
# 22    TotRms AbvGrd     2  mannwhitneyu  0.0019  Reject null hypothesis
# 23       Fireplaces     2  mannwhitneyu  0.1812  Accept null hypothesis
# 24    Garage Yr Blt     2  mannwhitneyu  0.0019  Reject null hypothesis
# 25      Garage Cars     2  mannwhitneyu  0.5355  Accept null hypothesis
# 26      Garage Area     2  mannwhitneyu  0.4821  Accept null hypothesis
# 27     Wood Deck SF     2  mannwhitneyu  0.1234  Accept null hypothesis
# 28    Open Porch SF     2  mannwhitneyu  0.3893  Accept null hypothesis
# 29   Enclosed Porch     2  mannwhitneyu  0.0643  Accept null hypothesis
# 30       3Ssn Porch     2  mannwhitneyu  0.6951  Accept null hypothesis
# 31     Screen Porch     2  mannwhitneyu  0.9858  Accept null hypothesis
# 32        Pool Area     2  mannwhitneyu  0.8249  Accept null hypothesis
# 33         Misc Val     2  mannwhitneyu  0.0001  Reject null hypothesis
# 34          Mo Sold     2  mannwhitneyu  0.3491  Accept null hypothesis
# 35          Yr Sold     2  mannwhitneyu  0.3438  Accept null hypothesis
# 36        SalePrice     2  mannwhitneyu  0.0002  Reject null hypothesis
#
#    kesimpulan
# 0       tidak
# 1       tidak
# 2       tidak
# 3         iya
# 4       tidak
# 5         iya
# 6         iya
# 7       tidak
# 8       tidak
# 9       tidak
# 10      tidak
# 11      tidak
# 12        iya
# 13      tidak
# 14      tidak
# 15        iya
# 16      tidak
# 17      tidak
# 18        iya
# 19      tidak
# 20        iya
# 21      tidak
# 22        iya
# 23      tidak
# 24        iya
# 25      tidak
# 26      tidak
# 27      tidak
# 28      tidak
# 29      tidak
# 30      tidak
# 31      tidak
# 32      tidak
# 33        iya
# 34      tidak
# 35      tidak
# 36        iya

# %%
df[df['Street']=='Grvl']
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 205            90        RM    110.000000      8472   Grvl       IR2
# 306            20   C (all)     66.000000      8712   Grvl       Reg
# 307            30   C (all)     66.000000      8712   Grvl       Reg
# 945            30   I (all)    109.000000     21780   Grvl       Reg
# 1359           30        RM     62.383721      6291   Grvl       IR1
# 1556           30   C (all)    120.000000     18000   Grvl       Reg
# 1557           70   C (all)     60.000000      9000   Grvl       Reg
# 1569          190        RL     81.303571    164660   Grvl       IR1
# 1628           20        RL    160.000000     18160   Grvl       Reg
# 2171           90        RL     81.000000     11841   Grvl       Reg
# 2268           20        RL     50.000000     35133   Grvl       Reg
# 2877           50   C (all)     60.000000      8520   Grvl       Reg
#
#      Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch  \
# 205           Bnk    AllPub     Corner        Mod  ...              0
# 306           Bnk    AllPub     Inside        Mod  ...              0
# 307           Lvl    AllPub     Corner        Gtl  ...            265
# 945           Lvl    NoSewr     Inside        Gtl  ...              0
# 1359          Lvl    AllPub     Inside        Gtl  ...             84
# 1556          Low    AllPub     Inside        Gtl  ...              0
# 1557          Bnk    AllPub     Inside        Gtl  ...            160
# 1569          HLS    AllPub     Corner        Sev  ...              0
# 1628          Lvl    AllPub     Inside        Gtl  ...            246
# 2171          Lvl    AllPub     Inside        Gtl  ...              0
# 2268          Lvl    AllPub     Inside        Mod  ...              0
# 2877          Bnk    AllPub     Inside        Gtl  ...              0
#
#      3Ssn Porch Screen Porch Pool Area Misc Val  Mo Sold  Yr Sold  Sale Type  \
# 205           0            0         0        0        5     2010        WD
# 306           0            0         0       54        6     2010        WD
# 307           0            0         0        0        6     2010        WD
# 945           0            0         0        0        3     2009      ConLD
# 1359          0            0         0        0        7     2008        WD
# 1556          0            0         0      560        8     2008      ConLD
# 1557          0            0         0        0        6     2008        WD
# 1569          0            0         0      700        8     2008        WD
# 1628          0            0         0        0        3     2007        WD
# 2171          0            0         0        0        5     2007        WD
# 2268          0          263         0        0        5     2007        WD
# 2877          0            0         0        0        4     2006        WD
#
#       Sale Condition SalePrice
# 205           Normal    110000
# 306           Alloca     55993
# 307           Alloca     50138
# 945           Normal     57625
# 1359          Normal     93850
# 1556          Normal     81000
# 1557          Normal     65000
# 1569          Normal    228950
# 1628          Alloca    154204
# 2171          Normal    118500
# 2268          Normal    186700
# 2877          Normal     78000
#
# [12 rows x 76 columns]

# %%
data[data['kesimpulan']=='iya']

# %%
data2=anova_t_normal(obj,'SalePrice',df,0.05)
data2
# Out:
#               nama  unik testnya   p value         hasil hipotesis kesimpulan
# 0        MS Zoning     7   anova    0.0000  Reject null hypothesis        iya
# 1           Street     2  t test  0.001275  Reject null hypothesis        iya
# 2           Street     2   anova    0.0013  Reject null hypothesis        iya
# 3        Lot Shape     4   anova    0.0000  Reject null hypothesis        iya
# 4     Land Contour     4   anova    0.0000  Reject null hypothesis        iya
# 5        Utilities     3   anova    0.2133  Accept null hypothesis      tidak
# 6       Lot Config     5   anova    0.0000  Reject null hypothesis        iya
# 7       Land Slope     3   anova    0.0010  Reject null hypothesis        iya
# 8     Neighborhood    28   anova    0.0000  Reject null hypothesis        iya
# 9      Condition 1     9   anova    0.0000  Reject null hypothesis        iya
# 10     Condition 2     8   anova    0.0000  Reject null hypothesis        iya
# 11       Bldg Type     5   anova    0.0000  Reject null hypothesis        iya
# 12     House Style     8   anova    0.0000  Reject null hypothesis        iya
# 13      Roof Style     6   anova    0.0000  Reject null hypothesis        iya
# 14       Roof Matl     7   anova    0.0000  Reject null hypothesis        iya
# 15    Exterior 1st    16   anova    0.0000  Reject null hypothesis        iya
# 16    Exterior 2nd    17   anova    0.0000  Reject null hypothesis        iya
# 17    Mas Vnr Type     5   anova    0.0000  Reject null hypothesis        iya
# 18      Exter Qual     4   anova    0.0000  Reject null hypothesis        iya
# 19      Exter Cond     5   anova    0.0000  Reject null hypothesis        iya
# 20      Foundation     6   anova    0.0000  Reject null hypothesis        iya
# 21       Bsmt Qual     6   anova    0.0000  Reject null hypothesis        iya
# 22       Bsmt Cond     6   anova    0.0000  Reject null hypothesis        iya
# 23   Bsmt Exposure     5   anova    0.0000  Reject null hypothesis        iya
# 24  BsmtFin Type 1     7   anova    0.0000  Reject null hypothesis        iya
# 25  BsmtFin Type 2     7   anova    0.0000  Reject null hypothesis        iya
# 26         Heating     6   anova    0.0000  Reject null hypothesis        iya
# 27      Heating QC     5   anova    0.0000  Reject null hypothesis        iya
# 28     Central Air     2  t test       0.0  Reject null hypothesis        iya
# 29     Central Air     2   anova    0.0000  Reject null hypothesis        iya
# 30      Electrical     5   anova    0.0000  Reject null hypothesis        iya
# 31    Kitchen Qual     5   anova    0.0000  Reject null hypothesis        iya
# 32      Functional     8   anova    0.0000  Reject null hypothesis        iya
# 33    Fireplace Qu     6   anova    0.0000  Reject null hypothesis        iya
# 34     Garage Type     7   anova    0.0000  Reject null hypothesis        iya
# 35   Garage Finish     4   anova    0.0000  Reject null hypothesis        iya
# 36     Garage Qual     6   anova    0.0000  Reject null hypothesis        iya
# 37     Garage Cond     6   anova    0.0000  Reject null hypothesis        iya
# 38     Paved Drive     3   anova    0.0000  Reject null hypothesis        iya
# 39       Sale Type    10   anova    0.0000  Reject null hypothesis        iya
# 40  Sale Condition     6   anova    0.0000  Reject null hypothesis        iya

# %%
data2[data2['kesimpulan']=='iya']
# Out:
#               nama  unik testnya   p value         hasil hipotesis kesimpulan
# 0        MS Zoning     7   anova    0.0000  Reject null hypothesis        iya
# 1           Street     2  t test  0.001275  Reject null hypothesis        iya
# 2           Street     2   anova    0.0013  Reject null hypothesis        iya
# 3        Lot Shape     4   anova    0.0000  Reject null hypothesis        iya
# 4     Land Contour     4   anova    0.0000  Reject null hypothesis        iya
# 6       Lot Config     5   anova    0.0000  Reject null hypothesis        iya
# 7       Land Slope     3   anova    0.0010  Reject null hypothesis        iya
# 8     Neighborhood    28   anova    0.0000  Reject null hypothesis        iya
# 9      Condition 1     9   anova    0.0000  Reject null hypothesis        iya
# 10     Condition 2     8   anova    0.0000  Reject null hypothesis        iya
# 11       Bldg Type     5   anova    0.0000  Reject null hypothesis        iya
# 12     House Style     8   anova    0.0000  Reject null hypothesis        iya
# 13      Roof Style     6   anova    0.0000  Reject null hypothesis        iya
# 14       Roof Matl     7   anova    0.0000  Reject null hypothesis        iya
# 15    Exterior 1st    16   anova    0.0000  Reject null hypothesis        iya
# 16    Exterior 2nd    17   anova    0.0000  Reject null hypothesis        iya
# 17    Mas Vnr Type     5   anova    0.0000  Reject null hypothesis        iya
# 18      Exter Qual     4   anova    0.0000  Reject null hypothesis        iya
# 19      Exter Cond     5   anova    0.0000  Reject null hypothesis        iya
# 20      Foundation     6   anova    0.0000  Reject null hypothesis        iya
# 21       Bsmt Qual     6   anova    0.0000  Reject null hypothesis        iya
# 22       Bsmt Cond     6   anova    0.0000  Reject null hypothesis        iya
# 23   Bsmt Exposure     5   anova    0.0000  Reject null hypothesis        iya
# 24  BsmtFin Type 1     7   anova    0.0000  Reject null hypothesis        iya
# 25  BsmtFin Type 2     7   anova    0.0000  Reject null hypothesis        iya
# 26         Heating     6   anova    0.0000  Reject null hypothesis        iya
# 27      Heating QC     5   anova    0.0000  Reject null hypothesis        iya
# 28     Central Air     2  t test       0.0  Reject null hypothesis        iya
# 29     Central Air     2   anova    0.0000  Reject null hypothesis        iya
# 30      Electrical     5   anova    0.0000  Reject null hypothesis        iya
# 31    Kitchen Qual     5   anova    0.0000  Reject null hypothesis        iya
# 32      Functional     8   anova    0.0000  Reject null hypothesis        iya
# 33    Fireplace Qu     6   anova    0.0000  Reject null hypothesis        iya
# 34     Garage Type     7   anova    0.0000  Reject null hypothesis        iya
# 35   Garage Finish     4   anova    0.0000  Reject null hypothesis        iya
# 36     Garage Qual     6   anova    0.0000  Reject null hypothesis        iya
# 37     Garage Cond     6   anova    0.0000  Reject null hypothesis        iya
# 38     Paved Drive     3   anova    0.0000  Reject null hypothesis        iya
# 39       Sale Type    10   anova    0.0000  Reject null hypothesis        iya
# 40  Sale Condition     6   anova    0.0000  Reject null hypothesis        iya

# %%
data2[data2['kesimpulan']=='tidak']
# Out:
#         nama  unik testnya p value         hasil hipotesis kesimpulan
# 5  Utilities     3   anova  0.2133  Accept null hypothesis      tidak

# %%
data[data['kesimpulan']=='tidak']
# Out:
#         nama  unik  testnya p value         hasil hipotesis kesimpulan
# 5  Utilities     3  kruskal  0.0962  Accept null hypothesis      tidak

# %%
sns.boxplot(data=df,x='Street',y='Lot Config')
# Out:
# <Axes: xlabel='Street', ylabel='Lot Config'>

# %%
sns.boxplot(data=df,x='Street',y='Utilities')
# Out:
# <Axes: xlabel='Street', ylabel='Utilities'>

# %%
Utilities 	3 	anova 	0.2133 	Accept null hypothesis 	tidak
6 	Lot Config
