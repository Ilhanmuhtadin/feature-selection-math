# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats



import seaborn as sns
import statsmodels.api as sm
import pandas as pd



from scipy.stats import shapiro,normaltest,kstest,jarque_bera
import pingouin as pg
from pingouin import kruskal

# %%
def ubah_notasi_ilmiah(value):
    formatted_value = "{:.4f}".format(value) if isinstance(value, float) else value
    return formatted_value
def anova_t_tidak_normal(xx,yy,full_data,p_vall):
    panjang_x=len(xx.columns)
    dataaaa=[]

    for i in range(panjang_x):

        dat=xx.describe().iloc[1][i]

        #print('\n\n')
        if dat<2:
              print(dat,xx.columns[i],'data mono')
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[[xx.columns[i]]]
            #print(data_s)
            unique_values = data_s.apply(lambda x: x.unique())

            data_s_1=full_data[full_data[xx.columns[i]]==unique_values.iloc[0][0]][yy]
            data_s_2=full_data[full_data[xx.columns[i]]==unique_values.iloc[1][0]][yy]
            #print(data_s_1)
            #print(data_s_2)


            ## now for the test

            t, p  = stats.mannwhitneyu(data_s_1, data_s_2)





            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                pakai='tidak'
                nilai='Accept null hypothesis'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                #print('Reject null hypothesis')
                pakai='iya'
            kesimp=[xx.columns[i],dat,'mannwhitneyu',p,nilai,pakai]
            dataaaa.append(kesimp)
        else:
            data_s=full_data[[xx.columns[i]]]
            unique_values = data_s.apply(lambda x: x.unique())

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx.columns[i],yy]]
            pp = kruskal(data=data_ss,dv=yy,between=xx.columns[i])
            p=pp['p-unc'].iloc[0]




        if p >p_vall:
            nilai='Accept null hypothesis'
            pakai='tidak'
            #print('Accept null hypothesis')
            #print(p)
        else:
            nilai='Reject null hypothesis'
            pakai='iya'
            #print('Reject null hypothesis')
            #print(p)

        kesimp=[xx.columns[i],dat,'kruskal',ubah_notasi_ilmiah(p),nilai,pakai]
        dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa
def anova_t_normal(xx,yy,full_data,p_vall):
    panjang_x=len(xx.columns)
    dataaaa=[]

    for i in range(panjang_x):

        dat=xx.describe().iloc[1][i]

        #print('\n\n')
        if dat<2:
            print(dat,xx.columns[i],'data mono')
        if dat ==2:
            #print(dat,xx.columns[i],'t')
            #print(full_data[[yy,xx.columns[i]]].head())
            data_s=full_data[[xx.columns[i]]]
            #print(data_s)
            unique_values = data_s.apply(lambda x: x.unique())

            data_s_1=full_data[full_data[xx.columns[i]]==unique_values.iloc[0][0]][yy]
            data_s_2=full_data[full_data[xx.columns[i]]==unique_values.iloc[1][0]][yy]
            #print(data_s_1)
            #print(data_s_2)


            # Performing the t-test
            t, p = stats.ttest_ind(data_s_1, data_s_2, equal_var=True)

            # Calculating the degrees of freedom
            df = len(data_s_1) + len(data_s_2) - 2

            # Outputting results

            #print(xx.columns[i])
            #print('t({}) = {}, p = {}'.format(df, t, p))

            # Conducting hypothesis testing
            if p > p_vall:
                nilai='Accept null hypothesis'
                pakai='tidak'
                #print('Accept null hypothesis')
            else:
                nilai='Reject null hypothesis'
                pakai='iya'
                #print('Reject null hypothesis')
            kesimp=[xx.columns[i],dat,'t test',p,nilai,pakai]
            dataaaa.append(kesimp)
        else:
            data_s=full_data[[xx.columns[i]]]
            unique_values = data_s.apply(lambda x: x.unique())

            #print(dat,xx.columns[i],'anova',unique_values)
            #print(full_data[[yy,xx.columns[i]]].head())
            data_ss=full_data[[xx.columns[i],yy]]

            pp=pg.anova(data=data_ss,dv=yy,between=xx.columns[i])
            p=pp['p-unc'].iloc[0]




        if p > p_vall:
            nilai='Accept null hypothesis'
            pakai='tidak'
            #print('Accept null hypothesis')
            #print(p)
        else:
            nilai='Reject null hypothesis'
            pakai='iya'
            #print('Reject null hypothesis')
            #print(p)

        kesimp=[xx.columns[i],dat,'anova',ubah_notasi_ilmiah(p),nilai,pakai]
        dataaaa.append(kesimp)

    dataaaa=pd.DataFrame(dataaaa)
    dataaaa.columns=['nama','unik','testnya','p value','hasil hipotesis','kesimpulan']
    return dataaaa

# %%
df = pd.read_csv('Ames_NO_Missing_Data.csv')
null_counts = df.isnull().sum()
columns_with_nulls = null_counts[null_counts > 0].index.tolist()
print("Columns with more than 0 null values:")
for col in columns_with_nulls:
    print(f"- {col}")
df.head()
# Out:
# Columns with more than 0 null values:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0           20        RL         141.0     31770   Pave       IR1
# 1           20        RH          80.0     11622   Pave       Reg
# 2           20        RL          81.0     14267   Pave       IR1
# 3           20        RL          93.0     11160   Pave       Reg
# 4           60        RL          74.0     13830   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch 3Ssn Porch  \
# 0          Lvl    AllPub     Corner        Gtl  ...              0          0
# 1          Lvl    AllPub     Inside        Gtl  ...              0          0
# 2          Lvl    AllPub     Corner        Gtl  ...              0          0
# 3          Lvl    AllPub     Corner        Gtl  ...              0          0
# 4          Lvl    AllPub     Inside        Gtl  ...              0          0
#
#   Screen Porch Pool Area Misc Val  Mo Sold  Yr Sold  Sale Type  \
# 0            0         0        0        5     2010        WD
# 1          120         0        0        6     2010        WD
# 2            0         0    12500        6     2010        WD
# 3            0         0        0        4     2010        WD
# 4            0         0        0        3     2010        WD
#
#    Sale Condition SalePrice
# 0          Normal    215000
# 1          Normal    105000
# 2          Normal    172000
# 3          Normal    244000
# 4          Normal    189900
#
# [5 rows x 76 columns]

# %%
obj=df.select_dtypes(include='O')

# %%
obj
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 1           RH   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 4           RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2920        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 2921        RL   Pave       IR1          Low    AllPub     Inside        Mod
# 2922        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2923        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
# 2924        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2  ... Kitchen Qual Functional  \
# 0           NAmes        Norm        Norm  ...           TA        Typ
# 1           NAmes       Feedr        Norm  ...           TA        Typ
# 2           NAmes        Norm        Norm  ...           Gd        Typ
# 3           NAmes        Norm        Norm  ...           Ex        Typ
# 4         Gilbert        Norm        Norm  ...           TA        Typ
# ...           ...         ...         ...  ...          ...        ...
# 2920      Mitchel        Norm        Norm  ...           TA        Typ
# 2921      Mitchel        Norm        Norm  ...           TA        Typ
# 2922      Mitchel        Norm        Norm  ...           TA        Typ
# 2923      Mitchel        Norm        Norm  ...           TA        Typ
# 2924      Mitchel        Norm        Norm  ...           TA        Typ
#
#      Fireplace Qu Garage Type Garage Finish Garage Qual Garage Cond  \
# 0              Gd      Attchd           Fin          TA          TA
# 1            None      Attchd           Unf          TA          TA
# 2            None      Attchd           Unf          TA          TA
# 3              TA      Attchd           Fin          TA          TA
# 4              TA      Attchd           Fin          TA          TA
# ...           ...         ...           ...         ...         ...
# 2920         None      Detchd           Unf          TA          TA
# 2921         None      Attchd           Unf          TA          TA
# 2922         None        None          None        None        None
# 2923           TA      Attchd           RFn          TA          TA
# 2924           TA      Attchd           Fin          TA          TA
#
#      Paved Drive Sale Type Sale Condition
# 0              P       WD          Normal
# 1              Y       WD          Normal
# 2              Y       WD          Normal
# 3              Y       WD          Normal
# 4              Y       WD          Normal
# ...          ...       ...            ...
# 2920           Y       WD          Normal
# 2921           Y       WD          Normal
# 2922           Y       WD          Normal
# 2923           Y       WD          Normal
# 2924           Y       WD          Normal
#
# [2925 rows x 39 columns]

# %%
data=anova_t_tidak_normal(obj,'SalePrice',df,0.05)
data
# Out:
#               nama  unik       testnya   p value         hasil hipotesis  \
# 0        MS Zoning     7       kruskal    0.0000  Reject null hypothesis
# 1           Street     2  mannwhitneyu  0.000243  Reject null hypothesis
# 2           Street     2       kruskal    0.0002  Reject null hypothesis
# 3        Lot Shape     4       kruskal    0.0000  Reject null hypothesis
# 4     Land Contour     4       kruskal    0.0000  Reject null hypothesis
# 5        Utilities     3       kruskal    0.0962  Accept null hypothesis
# 6       Lot Config     5       kruskal    0.0000  Reject null hypothesis
# 7       Land Slope     3       kruskal    0.0059  Reject null hypothesis
# 8     Neighborhood    28       kruskal    0.0000  Reject null hypothesis
# 9      Condition 1     9       kruskal    0.0000  Reject null hypothesis
# 10     Condition 2     8       kruskal    0.0000  Reject null hypothesis
# 11       Bldg Type     5       kruskal    0.0000  Reject null hypothesis
# 12     House Style     8       kruskal    0.0000  Reject null hypothesis
# 13      Roof Style     6       kruskal    0.0000  Reject null hypothesis
# 14       Roof Matl     7       kruskal    0.0005  Reject null hypothesis
# 15    Exterior 1st    16       kruskal    0.0000  Reject null hypothesis
# 16    Exterior 2nd    17       kruskal    0.0000  Reject null hypothesis
# 17    Mas Vnr Type     5       kruskal    0.0000  Reject null hypothesis
# 18      Exter Qual     4       kruskal    0.0000  Reject null hypothesis
# 19      Exter Cond     5       kruskal    0.0000  Reject null hypothesis
# 20      Foundation     6       kruskal    0.0000  Reject null hypothesis
# 21       Bsmt Qual     6       kruskal    0.0000  Reject null hypothesis
# 22       Bsmt Cond     6       kruskal    0.0000  Reject null hypothesis
# 23   Bsmt Exposure     5       kruskal    0.0000  Reject null hypothesis
# 24  BsmtFin Type 1     7       kruskal    0.0000  Reject null hypothesis
# 25  BsmtFin Type 2     7       kruskal    0.0000  Reject null hypothesis
# 26         Heating     6       kruskal    0.0000  Reject null hypothesis
# 27      Heating QC     5       kruskal    0.0000  Reject null hypothesis
# 28     Central Air     2  mannwhitneyu       0.0  Reject null hypothesis
# 29     Central Air     2       kruskal    0.0000  Reject null hypothesis
# 30      Electrical     5       kruskal    0.0000  Reject null hypothesis
# 31    Kitchen Qual     5       kruskal    0.0000  Reject null hypothesis
# 32      Functional     8       kruskal    0.0000  Reject null hypothesis
# 33    Fireplace Qu     6       kruskal    0.0000  Reject null hypothesis
# 34     Garage Type     7       kruskal    0.0000  Reject null hypothesis
# 35   Garage Finish     4       kruskal    0.0000  Reject null hypothesis
# 36     Garage Qual     6       kruskal    0.0000  Reject null hypothesis
# 37     Garage Cond     6       kruskal    0.0000  Reject null hypothesis
# 38     Paved Drive     3       kruskal    0.0000  Reject null hypothesis
# 39       Sale Type    10       kruskal    0.0000  Reject null hypothesis
# 40  Sale Condition     6       kruskal    0.0000  Reject null hypothesis
#
#    kesimpulan
# 0         iya
# 1         iya
# 2         iya
# 3         iya
# 4         iya
# 5       tidak
# 6         iya
# 7         iya
# 8         iya
# 9         iya
# 10        iya
# 11        iya
# 12        iya
# 13        iya
# 14        iya
# 15        iya
# 16        iya
# 17        iya
# 18        iya
# 19        iya
# 20        iya
# 21        iya
# 22        iya
# 23        iya
# 24        iya
# 25        iya
# 26        iya
# 27        iya
# 28        iya
# 29        iya
# 30        iya
# 31        iya
# 32        iya
# 33        iya
# 34        iya
# 35        iya
# 36        iya
# 37        iya
# 38        iya
# 39        iya
# 40        iya

# %%
data[data['kesimpulan']=='iya']
# Out:
#               nama  unik       testnya   p value         hasil hipotesis  \
# 0        MS Zoning     7       kruskal    0.0000  Reject null hypothesis
# 1           Street     2  mannwhitneyu  0.000243  Reject null hypothesis
# 2           Street     2       kruskal    0.0002  Reject null hypothesis
# 3        Lot Shape     4       kruskal    0.0000  Reject null hypothesis
# 4     Land Contour     4       kruskal    0.0000  Reject null hypothesis
# 6       Lot Config     5       kruskal    0.0000  Reject null hypothesis
# 7       Land Slope     3       kruskal    0.0059  Reject null hypothesis
# 8     Neighborhood    28       kruskal    0.0000  Reject null hypothesis
# 9      Condition 1     9       kruskal    0.0000  Reject null hypothesis
# 10     Condition 2     8       kruskal    0.0000  Reject null hypothesis
# 11       Bldg Type     5       kruskal    0.0000  Reject null hypothesis
# 12     House Style     8       kruskal    0.0000  Reject null hypothesis
# 13      Roof Style     6       kruskal    0.0000  Reject null hypothesis
# 14       Roof Matl     7       kruskal    0.0005  Reject null hypothesis
# 15    Exterior 1st    16       kruskal    0.0000  Reject null hypothesis
# 16    Exterior 2nd    17       kruskal    0.0000  Reject null hypothesis
# 17    Mas Vnr Type     5       kruskal    0.0000  Reject null hypothesis
# 18      Exter Qual     4       kruskal    0.0000  Reject null hypothesis
# 19      Exter Cond     5       kruskal    0.0000  Reject null hypothesis
# 20      Foundation     6       kruskal    0.0000  Reject null hypothesis
# 21       Bsmt Qual     6       kruskal    0.0000  Reject null hypothesis
# 22       Bsmt Cond     6       kruskal    0.0000  Reject null hypothesis
# 23   Bsmt Exposure     5       kruskal    0.0000  Reject null hypothesis
# 24  BsmtFin Type 1     7       kruskal    0.0000  Reject null hypothesis
# 25  BsmtFin Type 2     7       kruskal    0.0000  Reject null hypothesis
# 26         Heating     6       kruskal    0.0000  Reject null hypothesis
# 27      Heating QC     5       kruskal    0.0000  Reject null hypothesis
# 28     Central Air     2  mannwhitneyu       0.0  Reject null hypothesis
# 29     Central Air     2       kruskal    0.0000  Reject null hypothesis
# 30      Electrical     5       kruskal    0.0000  Reject null hypothesis
# 31    Kitchen Qual     5       kruskal    0.0000  Reject null hypothesis
# 32      Functional     8       kruskal    0.0000  Reject null hypothesis
# 33    Fireplace Qu     6       kruskal    0.0000  Reject null hypothesis
# 34     Garage Type     7       kruskal    0.0000  Reject null hypothesis
# 35   Garage Finish     4       kruskal    0.0000  Reject null hypothesis
# 36     Garage Qual     6       kruskal    0.0000  Reject null hypothesis
# 37     Garage Cond     6       kruskal    0.0000  Reject null hypothesis
# 38     Paved Drive     3       kruskal    0.0000  Reject null hypothesis
# 39       Sale Type    10       kruskal    0.0000  Reject null hypothesis
# 40  Sale Condition     6       kruskal    0.0000  Reject null hypothesis
#
#    kesimpulan
# 0         iya
# 1         iya
# 2         iya
# 3         iya
# 4         iya
# 6         iya
# 7         iya
# 8         iya
# 9         iya
# 10        iya
# 11        iya
# 12        iya
# 13        iya
# 14        iya
# 15        iya
# 16        iya
# 17        iya
# 18        iya
# 19        iya
# 20        iya
# 21        iya
# 22        iya
# 23        iya
# 24        iya
# 25        iya
# 26        iya
# 27        iya
# 28        iya
# 29        iya
# 30        iya
# 31        iya
# 32        iya
# 33        iya
# 34        iya
# 35        iya
# 36        iya
# 37        iya
# 38        iya
# 39        iya
# 40        iya

# %%
data2=anova_t_normal(obj,'SalePrice',df,0.05)
data2
# Out:
#               nama  unik testnya   p value         hasil hipotesis kesimpulan
# 0        MS Zoning     7   anova    0.0000  Reject null hypothesis        iya
# 1           Street     2  t test  0.001275  Reject null hypothesis        iya
# 2           Street     2   anova    0.0013  Reject null hypothesis        iya
# 3        Lot Shape     4   anova    0.0000  Reject null hypothesis        iya
# 4     Land Contour     4   anova    0.0000  Reject null hypothesis        iya
# 5        Utilities     3   anova    0.2133  Accept null hypothesis      tidak
# 6       Lot Config     5   anova    0.0000  Reject null hypothesis        iya
# 7       Land Slope     3   anova    0.0010  Reject null hypothesis        iya
# 8     Neighborhood    28   anova    0.0000  Reject null hypothesis        iya
# 9      Condition 1     9   anova    0.0000  Reject null hypothesis        iya
# 10     Condition 2     8   anova    0.0000  Reject null hypothesis        iya
# 11       Bldg Type     5   anova    0.0000  Reject null hypothesis        iya
# 12     House Style     8   anova    0.0000  Reject null hypothesis        iya
# 13      Roof Style     6   anova    0.0000  Reject null hypothesis        iya
# 14       Roof Matl     7   anova    0.0000  Reject null hypothesis        iya
# 15    Exterior 1st    16   anova    0.0000  Reject null hypothesis        iya
# 16    Exterior 2nd    17   anova    0.0000  Reject null hypothesis        iya
# 17    Mas Vnr Type     5   anova    0.0000  Reject null hypothesis        iya
# 18      Exter Qual     4   anova    0.0000  Reject null hypothesis        iya
# 19      Exter Cond     5   anova    0.0000  Reject null hypothesis        iya
# 20      Foundation     6   anova    0.0000  Reject null hypothesis        iya
# 21       Bsmt Qual     6   anova    0.0000  Reject null hypothesis        iya
# 22       Bsmt Cond     6   anova    0.0000  Reject null hypothesis        iya
# 23   Bsmt Exposure     5   anova    0.0000  Reject null hypothesis        iya
# 24  BsmtFin Type 1     7   anova    0.0000  Reject null hypothesis        iya
# 25  BsmtFin Type 2     7   anova    0.0000  Reject null hypothesis        iya
# 26         Heating     6   anova    0.0000  Reject null hypothesis        iya
# 27      Heating QC     5   anova    0.0000  Reject null hypothesis        iya
# 28     Central Air     2  t test       0.0  Reject null hypothesis        iya
# 29     Central Air     2   anova    0.0000  Reject null hypothesis        iya
# 30      Electrical     5   anova    0.0000  Reject null hypothesis        iya
# 31    Kitchen Qual     5   anova    0.0000  Reject null hypothesis        iya
# 32      Functional     8   anova    0.0000  Reject null hypothesis        iya
# 33    Fireplace Qu     6   anova    0.0000  Reject null hypothesis        iya
# 34     Garage Type     7   anova    0.0000  Reject null hypothesis        iya
# 35   Garage Finish     4   anova    0.0000  Reject null hypothesis        iya
# 36     Garage Qual     6   anova    0.0000  Reject null hypothesis        iya
# 37     Garage Cond     6   anova    0.0000  Reject null hypothesis        iya
# 38     Paved Drive     3   anova    0.0000  Reject null hypothesis        iya
# 39       Sale Type    10   anova    0.0000  Reject null hypothesis        iya
# 40  Sale Condition     6   anova    0.0000  Reject null hypothesis        iya

# %%
data2[data2['kesimpulan']=='iya']
# Out:
#               nama  unik testnya   p value         hasil hipotesis kesimpulan
# 0        MS Zoning     7   anova    0.0000  Reject null hypothesis        iya
# 1           Street     2  t test  0.001275  Reject null hypothesis        iya
# 2           Street     2   anova    0.0013  Reject null hypothesis        iya
# 3        Lot Shape     4   anova    0.0000  Reject null hypothesis        iya
# 4     Land Contour     4   anova    0.0000  Reject null hypothesis        iya
# 6       Lot Config     5   anova    0.0000  Reject null hypothesis        iya
# 7       Land Slope     3   anova    0.0010  Reject null hypothesis        iya
# 8     Neighborhood    28   anova    0.0000  Reject null hypothesis        iya
# 9      Condition 1     9   anova    0.0000  Reject null hypothesis        iya
# 10     Condition 2     8   anova    0.0000  Reject null hypothesis        iya
# 11       Bldg Type     5   anova    0.0000  Reject null hypothesis        iya
# 12     House Style     8   anova    0.0000  Reject null hypothesis        iya
# 13      Roof Style     6   anova    0.0000  Reject null hypothesis        iya
# 14       Roof Matl     7   anova    0.0000  Reject null hypothesis        iya
# 15    Exterior 1st    16   anova    0.0000  Reject null hypothesis        iya
# 16    Exterior 2nd    17   anova    0.0000  Reject null hypothesis        iya
# 17    Mas Vnr Type     5   anova    0.0000  Reject null hypothesis        iya
# 18      Exter Qual     4   anova    0.0000  Reject null hypothesis        iya
# 19      Exter Cond     5   anova    0.0000  Reject null hypothesis        iya
# 20      Foundation     6   anova    0.0000  Reject null hypothesis        iya
# 21       Bsmt Qual     6   anova    0.0000  Reject null hypothesis        iya
# 22       Bsmt Cond     6   anova    0.0000  Reject null hypothesis        iya
# 23   Bsmt Exposure     5   anova    0.0000  Reject null hypothesis        iya
# 24  BsmtFin Type 1     7   anova    0.0000  Reject null hypothesis        iya
# 25  BsmtFin Type 2     7   anova    0.0000  Reject null hypothesis        iya
# 26         Heating     6   anova    0.0000  Reject null hypothesis        iya
# 27      Heating QC     5   anova    0.0000  Reject null hypothesis        iya
# 28     Central Air     2  t test       0.0  Reject null hypothesis        iya
# 29     Central Air     2   anova    0.0000  Reject null hypothesis        iya
# 30      Electrical     5   anova    0.0000  Reject null hypothesis        iya
# 31    Kitchen Qual     5   anova    0.0000  Reject null hypothesis        iya
# 32      Functional     8   anova    0.0000  Reject null hypothesis        iya
# 33    Fireplace Qu     6   anova    0.0000  Reject null hypothesis        iya
# 34     Garage Type     7   anova    0.0000  Reject null hypothesis        iya
# 35   Garage Finish     4   anova    0.0000  Reject null hypothesis        iya
# 36     Garage Qual     6   anova    0.0000  Reject null hypothesis        iya
# 37     Garage Cond     6   anova    0.0000  Reject null hypothesis        iya
# 38     Paved Drive     3   anova    0.0000  Reject null hypothesis        iya
# 39       Sale Type    10   anova    0.0000  Reject null hypothesis        iya
# 40  Sale Condition     6   anova    0.0000  Reject null hypothesis        iya

# %%
data2[data2['kesimpulan']=='tidak']
# Out:
#         nama  unik testnya p value         hasil hipotesis kesimpulan
# 5  Utilities     3   anova  0.2133  Accept null hypothesis      tidak

# %%
data[data['kesimpulan']=='tidak']
# Out:
#         nama  unik  testnya p value         hasil hipotesis kesimpulan
# 5  Utilities     3  kruskal  0.0962  Accept null hypothesis      tidak

# %%
sns.boxplot(data=df,x='Utilities',y='SalePrice')
# Out:
# <Axes: xlabel='Utilities', ylabel='SalePrice'>

# %%
drop Utilities
